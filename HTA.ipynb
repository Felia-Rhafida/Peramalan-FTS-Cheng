# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
from collections import Counter
import numpy as np

def Semesta(Data, D1, D2):
    semesta = [min(Data) - D1, max(Data) + D2]
    return semesta
    
def Interval(Data, D1, D2):
    rentang = (max(Data) + D2) - (min(Data) - D1)
    n = len(Data)
    K = 1 + 3.322 * math.log10(n)
    I = round(rentang / K)
    qtyInterval = round(rentang / I)
    return rentang, K, I, qtyInterval

def HimpunanFuzzy(I, qtyInterval, dmin):
    kelas = []
    bBawah = []
    bAtas = []
    nTengah = []
    nilai = dmin
    dataDict = {}
    for i in range(1, qtyInterval + 1):
        kelas.append("A" + str(i))
        batasBawah = nilai
        batasAtas = nilai + I
        nilaiTengah = (batasBawah + batasAtas) / 2
        bBawah.append(int(batasBawah))
        bAtas.append(int(batasAtas))
        nTengah.append(int(nilaiTengah))
        nilai = batasAtas
    for i in range(0, len(kelas)):
        dataDict[kelas[i]] = {"nilai": nTengah[i]}
    return kelas, bBawah, bAtas, nTengah, dataDict

def Fuzzifikasi(kelompok, kelas, data):
    fuzzifikasi = []
    for nilai in data:
        for i, k in enumerate(kelompok):
            if nilai < k:
                fuzzifikasi.append(kelas[i])
                break
    return fuzzifikasi

def FLR(fuzzifikasi):
    flr = []
    for i in range(len(fuzzifikasi)):
        if i < 1:
            flr.append(f">> {fuzzifikasi[i]}")
        else:
            flr.append(f"{fuzzifikasi[i-1]} >> {fuzzifikasi[i]}")
    return flr

def FLRG(data):
    dictFLRG = {}
    for i in range(len(data) - 1):
        current_state = data[i]
        next_state = data[i + 1]
        if current_state not in dictFLRG:
            dictFLRG[current_state] = []
        dictFLRG[current_state].append(next_state)
    for current_state, next_states in dictFLRG.items():
        dictFLRG[current_state] = list(next_states)  
    return dictFLRG

def Pembobotan(data):
    flrg = []
    bobot = []
    pembobotan = []
    for i in data:
        element_count = Counter(i)
        result = list(element_count.values())
        result2 = list(element_count.keys())
        bobot.append(result)
        flrg.append(result2)
        comper = [round((x / sum(result)), 2) for x in result]
        pembobotan.append(comper)
    return bobot, pembobotan , flrg

def Defuzzifikasi(flrgroup, bobot, newflrg):
    key = flrgroup.keys()
    list_key = list(key) 
    defuzzifikasi = []
    dictDefuzzifikasi = {}
    flrgnew = []
    for i in range(len(newflrg)):
        row = []
        for j in range(len(newflrg[i])):
            if newflrg[i][j] in dataDict:
                row.append(dataDict[newflrg[i][j]]['nilai'])
        flrgnew.append(row)
    for i in range(len(flrgnew)):
        row = []
        for j in range(len(flrgnew[i])):
            result = flrgnew[i][j] * bobot[i][j]
            row.append(round(result))
        defuzzifikasi.append(row)
    for i in range(len(defuzzifikasi)):
        dictDefuzzifikasi[list_key[i]] = sum(defuzzifikasi[i])
    return dictDefuzzifikasi

def Peramalan(fuzzifikasi, defuzzifikasi):
    peramalan = []
    for i in fuzzifikasi:
        peramalan.append(defuzzifikasi[i])
    return peramalan
    
def MAPE(actual_values, predicted_values): 
    actual_values, predicted_values = np.array(actual_values), np.array(predicted_values)
    n = len(actual_values)
    mape = (1/n) * sum(abs((actual_values[i] - predicted_values[i]) / actual_values[i]) * 100 for i in range(n))
    return mape
    
def calculate_percentage_error(actual, predicted):
    errors = []
    for i in range(len(actual)):
        error = abs((actual[i] - predicted[i]) / actual[i]) * 100
        errors.append(error)
    return errors
    
file_path = 'C:/Users/Lenovo/Documents/fts cheng/bismillah2.xlsx'
df = pd.read_excel(file_path)
time_series_column = 'HTA'
D1= 1
D2= 1

semesta = Semesta(df[time_series_column], D1=D1, D2=D2)
rentang, K, I, qty_interval = Interval(df[time_series_column], D1=D1, D2=D2)
kelas, bBawah, bAtas, nTengah, dataDict = HimpunanFuzzy(I, qty_interval, min(df[time_series_column]))
kelompok = bAtas
fuzzifikasi = Fuzzifikasi(kelompok, kelas, df[time_series_column])
flr = FLR(fuzzifikasi)
flr_grouped = FLRG(fuzzifikasi)
bobot, pembobotan, flrg = Pembobotan(flr_grouped.values())
defuzzifikasi= Defuzzifikasi(flr_grouped, pembobotan, flrg)
peramalan = Peramalan(fuzzifikasi, defuzzifikasi)
mape = MAPE(df[time_series_column], peramalan)
mape_percentage = f"{mape:.2f}%"
data_aktual = df[time_series_column]
data_prediksi = peramalan
errors = calculate_percentage_error(data_aktual, data_prediksi)
for i in range(len(data_aktual)):
    actual_value = data_aktual[i]
    predicted_value = data_prediksi[i]
    error = errors[i]
    print(f"Data ke-{i + 1}: Aktual = {actual_value}, Prediksi = {predicted_value}, Persentase Error = {error:.2f}%")
print(f"Himpunan Semesta Fuzzy (U): {semesta}")
print(f"Rentang: {rentang}")
print(f"K: {K}")
print(f"Interval: {I}")
print(f"Jumlah Interval: {qty_interval}")
print(f"Kelas: {kelas}")
print(f"Batas Bawah: {bBawah}")
print(f"Batas Atas: {bAtas}")
print(f"Nilai Tengah: {nTengah}")
print("Data Dictionary:")
for key, value in dataDict.items():
    print(f"{key}: {value}")
print(f"Fuzzifikasi: {fuzzifikasi}")
print(f"Fuzzy Logic Relation: {flr}")
#print(f"FLR Grouped: {flr_grouped}")
print("FLRG:")
for key, value in flr_grouped.items():
    print(f"{key}: {value}")
print(f"Bobot: {bobot}")
print(f"Pembobotan: {pembobotan}")
print(f"flrg: {flrg}")
print(f"Defuzzifikasi: {defuzzifikasi}")
print(f"peramalan: {peramalan}")
print(f'MAPE: {mape_percentage}')

plt.figure(figsize=(10, 6))
plt.plot(df[time_series_column][1:], label='Aktual', color='green')
plt.title('Data Aktual')
plt.xlabel('Jumlah Data')
plt.ylabel('Jumlah')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Plot data aktual
plt.figure(figsize=(10, 6))
plt.plot(df[time_series_column][1:], label='Aktual', color='green')
# Plot hasil peramalan
plt.plot(peramalan, label='Peramalan', color='red')
plt.title('Peramalan vs Aktual')
plt.xlabel('Jumlah Data')
plt.ylabel('Jumlah penjualan')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# Data ke-1: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-2: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-3: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-4: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-5: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-6: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-7: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-8: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-9: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-10: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-11: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-12: Aktual = 7, Prediksi = 11, Persentase Error = 57.14%
# Data ke-13: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-14: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-15: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-16: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-17: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-18: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-19: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-20: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-21: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-22: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-23: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-24: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-25: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-26: Aktual = 13, Prediksi = 11, Persentase Error = 15.38%
# Data ke-27: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-28: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-29: Aktual = 13, Prediksi = 11, Persentase Error = 15.38%
# Data ke-30: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-31: Aktual = 13, Prediksi = 11, Persentase Error = 15.38%
# Data ke-32: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-33: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-34: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-35: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-36: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-37: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-38: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-39: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-40: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-41: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-42: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-43: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-44: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-45: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-46: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-47: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-48: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-49: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-50: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-51: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-52: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-53: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-54: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-55: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-56: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-57: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-58: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-59: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-60: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-61: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-62: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-63: Aktual = 4, Prediksi = 12, Persentase Error = 200.00%
# Data ke-64: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-65: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-66: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-67: Aktual = 5, Prediksi = 12, Persentase Error = 140.00%
# Data ke-68: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-69: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-70: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-71: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-72: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-73: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-74: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-75: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-76: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-77: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-78: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-79: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-80: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-81: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-82: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-83: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-84: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-85: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-86: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-87: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-88: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-89: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-90: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-91: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-92: Aktual = 7, Prediksi = 11, Persentase Error = 57.14%
# Data ke-93: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-94: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-95: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-96: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-97: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-98: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-99: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-100: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-101: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-102: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-103: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-104: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-105: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-106: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-107: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-108: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-109: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-110: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-111: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-112: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-113: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-114: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-115: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-116: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-117: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-118: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-119: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-120: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-121: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-122: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-123: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-124: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-125: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-126: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-127: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-128: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-129: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-130: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-131: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-132: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-133: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-134: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-135: Aktual = 13, Prediksi = 11, Persentase Error = 15.38%
# Data ke-136: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-137: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-138: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-139: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-140: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-141: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-142: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-143: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-144: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-145: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-146: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-147: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-148: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-149: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-150: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-151: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-152: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-153: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-154: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-155: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-156: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-157: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-158: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-159: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-160: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-161: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-162: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-163: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-164: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-165: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-166: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-167: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-168: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-169: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-170: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-171: Aktual = 15, Prediksi = 12, Persentase Error = 20.00%
# Data ke-172: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-173: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-174: Aktual = 15, Prediksi = 12, Persentase Error = 20.00%
# Data ke-175: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-176: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-177: Aktual = 15, Prediksi = 12, Persentase Error = 20.00%
# Data ke-178: Aktual = 13, Prediksi = 11, Persentase Error = 15.38%
# Data ke-179: Aktual = 2, Prediksi = 13, Persentase Error = 550.00%
# Data ke-180: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-181: Aktual = 12, Prediksi = 11, Persentase Error = 8.33%
# Data ke-182: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-183: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-184: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-185: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-186: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-187: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-188: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-189: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-190: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-191: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-192: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-193: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-194: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-195: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-196: Aktual = 5, Prediksi = 12, Persentase Error = 140.00%
# Data ke-197: Aktual = 9, Prediksi = 10, Persentase Error = 11.11%
# Data ke-198: Aktual = 7, Prediksi = 11, Persentase Error = 57.14%
# Data ke-199: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-200: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-201: Aktual = 11, Prediksi = 10, Persentase Error = 9.09%
# Data ke-202: Aktual = 10, Prediksi = 10, Persentase Error = 0.00%
# Data ke-203: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-204: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Data ke-205: Aktual = 8, Prediksi = 10, Persentase Error = 25.00%
# Data ke-206: Aktual = 14, Prediksi = 12, Persentase Error = 14.29%
# Himpunan Semesta Fuzzy (U): [1, 16]
# Rentang: 15
# K: 8.686666906066328
# Interval: 2
# Jumlah Interval: 8
# Kelas: ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8']
# Batas Bawah: [2, 4, 6, 8, 10, 12, 14, 16]
# Batas Atas: [4, 6, 8, 10, 12, 14, 16, 18]
# Nilai Tengah: [3, 5, 7, 9, 11, 13, 15, 17]
# Data Dictionary:
# A1: {'nilai': 3}
# A2: {'nilai': 5}
# A3: {'nilai': 7}
# A4: {'nilai': 9}
# A5: {'nilai': 11}
# A6: {'nilai': 13}
# A7: {'nilai': 15}
# A8: {'nilai': 17}
# Fuzzifikasi: ['A5', 'A7', 'A7', 'A7', 'A7', 'A7', 'A5', 'A4', 'A5', 'A5', 'A5', 'A3', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A5', 'A7', 'A4', 'A7', 'A7', 'A6', 'A6', 'A7', 'A7', 'A6', 'A7', 'A6', 'A5', 'A5', 'A4', 'A6', 'A5', 'A5', 'A4', 'A4', 'A5', 'A4', 'A5', 'A4', 'A5', 'A7', 'A7', 'A7', 'A5', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A7', 'A6', 'A5', 'A7', 'A7', 'A5', 'A2', 'A7', 'A7', 'A7', 'A2', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A7', 'A7', 'A7', 'A7', 'A3', 'A7', 'A7', 'A7', 'A7', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A6', 'A6', 'A6', 'A5', 'A4', 'A5', 'A4', 'A5', 'A4', 'A6', 'A6', 'A6', 'A4', 'A4', 'A5', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A7', 'A7', 'A7', 'A6', 'A6', 'A6', 'A6', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A7', 'A7', 'A7', 'A7', 'A7', 'A5', 'A5', 'A5', 'A4', 'A7', 'A4', 'A7', 'A4', 'A7', 'A4', 'A7', 'A4', 'A7', 'A5', 'A4', 'A5', 'A5', 'A5', 'A7', 'A6', 'A7', 'A7', 'A7', 'A4', 'A7', 'A7', 'A7', 'A7', 'A6', 'A1', 'A6', 'A6', 'A4', 'A4', 'A4', 'A4', 'A5', 'A4', 'A4', 'A5', 'A5', 'A5', 'A5', 'A5', 'A7', 'A4', 'A2', 'A4', 'A3', 'A4', 'A7', 'A5', 'A5', 'A7', 'A7', 'A4', 'A7']
# Fuzzy Logic Relation: ['>> A5', 'A5 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A3', 'A3 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A5', 'A5 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A7', 'A7 >> A6', 'A6 >> A6', 'A6 >> A7', 'A7 >> A7', 'A7 >> A6', 'A6 >> A7', 'A7 >> A6', 'A6 >> A5', 'A5 >> A5', 'A5 >> A4', 'A4 >> A6', 'A6 >> A5', 'A5 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A5', 'A5 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A7', 'A7 >> A6', 'A6 >> A5', 'A5 >> A7', 'A7 >> A7', 'A7 >> A5', 'A5 >> A2', 'A2 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A2', 'A2 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A3', 'A3 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A6', 'A6 >> A6', 'A6 >> A6', 'A6 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A6', 'A6 >> A6', 'A6 >> A6', 'A6 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A6', 'A6 >> A6', 'A6 >> A6', 'A6 >> A6', 'A6 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A4', 'A4 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A5', 'A5 >> A4', 'A4 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A7', 'A7 >> A6', 'A6 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A4', 'A4 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A7', 'A7 >> A6', 'A6 >> A1', 'A1 >> A6', 'A6 >> A6', 'A6 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A4', 'A4 >> A4', 'A4 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A5', 'A5 >> A7', 'A7 >> A4', 'A4 >> A2', 'A2 >> A4', 'A4 >> A3', 'A3 >> A4', 'A4 >> A7', 'A7 >> A5', 'A5 >> A5', 'A5 >> A7', 'A7 >> A7', 'A7 >> A4', 'A4 >> A7']
# FLRG:
# A5: ['A7', 'A4', 'A5', 'A5', 'A3', 'A5', 'A7', 'A5', 'A4', 'A5', 'A4', 'A4', 'A4', 'A7', 'A5', 'A4', 'A7', 'A7', 'A2', 'A4', 'A4', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A6', 'A4', 'A4', 'A4', 'A5', 'A4', 'A5', 'A5', 'A4', 'A4', 'A5', 'A5', 'A7', 'A4', 'A5', 'A5', 'A5', 'A5', 'A7', 'A5', 'A7']
# A7: ['A7', 'A7', 'A7', 'A7', 'A5', 'A4', 'A7', 'A6', 'A7', 'A6', 'A6', 'A7', 'A7', 'A5', 'A6', 'A7', 'A5', 'A7', 'A7', 'A2', 'A7', 'A7', 'A7', 'A3', 'A7', 'A7', 'A7', 'A5', 'A7', 'A7', 'A6', 'A7', 'A7', 'A7', 'A7', 'A5', 'A4', 'A4', 'A4', 'A4', 'A5', 'A6', 'A7', 'A7', 'A4', 'A7', 'A7', 'A7', 'A6', 'A4', 'A5', 'A7', 'A4']
# A4: ['A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A7', 'A6', 'A4', 'A5', 'A5', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A7', 'A5', 'A5', 'A6', 'A4', 'A5', 'A4', 'A4', 'A4', 'A4', 'A7', 'A4', 'A4', 'A4', 'A4', 'A4', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A5', 'A7', 'A4', 'A4', 'A4', 'A5', 'A4', 'A5', 'A2', 'A3', 'A7', 'A7']
# A3: ['A4', 'A7', 'A4']
# A6: ['A6', 'A7', 'A7', 'A5', 'A5', 'A5', 'A6', 'A6', 'A5', 'A6', 'A6', 'A4', 'A6', 'A6', 'A6', 'A4', 'A7', 'A1', 'A6', 'A4']
# A2: ['A7', 'A5', 'A4']
# A1: ['A6']
# Bobot: [[8, 15, 29, 1, 1, 1], [29, 7, 8, 7, 1, 1], [13, 41, 12, 2, 1, 1], [2, 1], [9, 3, 4, 3, 1], [1, 1, 1], [1]]
# Pembobotan: [[0.15, 0.27, 0.53, 0.02, 0.02, 0.02], [0.55, 0.13, 0.15, 0.13, 0.02, 0.02], [0.19, 0.59, 0.17, 0.03, 0.01, 0.01], [0.67, 0.33], [0.45, 0.15, 0.2, 0.15, 0.05], [0.33, 0.33, 0.33], [1.0]]
# flrg: [['A7', 'A4', 'A5', 'A3', 'A2', 'A6'], ['A7', 'A5', 'A4', 'A6', 'A2', 'A3'], ['A5', 'A4', 'A7', 'A6', 'A2', 'A3'], ['A4', 'A7'], ['A6', 'A7', 'A5', 'A4', 'A1'], ['A7', 'A5', 'A4'], ['A6']]
# Defuzzifikasi: {'A5': 10, 'A7': 12, 'A4': 10, 'A3': 11, 'A6': 11, 'A2': 12, 'A1': 13}
# peramalan: [10, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 11, 10, 10, 10, 10, 10, 10, 10, 10, 12, 10, 12, 12, 11, 11, 12, 12, 11, 12, 11, 10, 10, 10, 11, 10, 10, 10, 10, 10, 10, 10, 10, 10, 12, 12, 12, 10, 10, 10, 10, 10, 10, 10, 10, 10, 12, 11, 10, 12, 12, 10, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 12, 12, 12, 12, 11, 12, 12, 12, 12, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 11, 11, 11, 10, 10, 10, 10, 10, 10, 11, 11, 11, 10, 10, 10, 10, 10, 10, 10, 10, 10, 12, 12, 12, 11, 11, 11, 11, 10, 10, 10, 10, 10, 10, 12, 12, 12, 12, 12, 10, 10, 10, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 10, 10, 10, 10, 12, 11, 12, 12, 12, 10, 12, 12, 12, 12, 11, 13, 11, 11, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 12, 10, 12, 10, 11, 10, 12, 10, 10, 12, 12, 10, 12]
# MAPE: 17.58%
